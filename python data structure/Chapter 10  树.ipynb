# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#树的概览" data-toc-modified-id="树的概览-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>树的概览</a></span><ul class="toc-item"><li><span><a href="#树的术语" data-toc-modified-id="树的术语-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>树的术语</a></span></li><li><span><a href="#普通的树和二叉树" data-toc-modified-id="普通的树和二叉树-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>普通的树和二叉树</a></span></li></ul></li><li><span><a href="#为什么要使用树" data-toc-modified-id="为什么要使用树-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>为什么要使用树</a></span></li><li><span><a href="#二叉树的形状" data-toc-modified-id="二叉树的形状-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>二叉树的形状</a></span></li><li><span><a href="#二叉树的三种常见应用" data-toc-modified-id="二叉树的三种常见应用-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>二叉树的三种常见应用</a></span><ul class="toc-item"><li><span><a href="#堆" data-toc-modified-id="堆-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>堆</a></span></li><li><span><a href="#二叉搜索树（BST）" data-toc-modified-id="二叉搜索树（BST）-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>二叉搜索树（BST）</a></span></li><li><span><a href="#表达式树" data-toc-modified-id="表达式树-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>表达式树</a></span></li></ul></li><li><span><a href="#二叉树的遍历" data-toc-modified-id="二叉树的遍历-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>二叉树的遍历</a></span><ul class="toc-item"><li><span><a href="#前序遍历" data-toc-modified-id="前序遍历-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>前序遍历</a></span></li><li><span><a href="#中序遍历" data-toc-modified-id="中序遍历-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>中序遍历</a></span></li><li><span><a href="#后序遍历" data-toc-modified-id="后序遍历-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>后序遍历</a></span></li><li><span><a href="#层序遍历" data-toc-modified-id="层序遍历-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>层序遍历</a></span></li></ul></li><li><span><a href="#开发二叉搜素树" data-toc-modified-id="开发二叉搜素树-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>开发二叉搜素树</a></span><ul class="toc-item"><li><span><a href="#二叉搜索树接口" data-toc-modified-id="二叉搜索树接口-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>二叉搜索树接口</a></span></li><li><span><a href="#链表实现的数据结构" data-toc-modified-id="链表实现的数据结构-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>链表实现的数据结构</a></span><ul class="toc-item"><li><span><a href="#搜索二叉搜索树" data-toc-modified-id="搜索二叉搜索树-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>搜索二叉搜索树</a></span></li><li><span><a href="#遍历二叉搜索树" data-toc-modified-id="遍历二叉搜索树-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>遍历二叉搜索树</a></span></li><li><span><a href="#二叉搜索树的字符串表示" data-toc-modified-id="二叉搜索树的字符串表示-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>二叉搜索树的字符串表示</a></span></li><li><span><a href="#在二叉搜索树中插入一项" data-toc-modified-id="在二叉搜索树中插入一项-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>在二叉搜索树中插入一项</a></span></li><li><span><a href="#在二叉搜索树中删除一项" data-toc-modified-id="在二叉搜索树中删除一项-6.2.5"><span class="toc-item-num">6.2.5&nbsp;&nbsp;</span>在二叉搜索树中删除一项</a></span></li><li><span><a href="#复杂度分析" data-toc-modified-id="复杂度分析-6.2.6"><span class="toc-item-num">6.2.6&nbsp;&nbsp;</span>复杂度分析</a></span></li></ul></li></ul></li><li><span><a href="#二叉树的数组实现" data-toc-modified-id="二叉树的数组实现-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>二叉树的数组实现</a></span></li><li><span><a href="#堆" data-toc-modified-id="堆-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>堆</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Summary</a></span></li></ul></div>

# %% [markdown]
# 层级结构
#
# 树还可以用于实现其他的集合，如有序的集和有序的字典，优先级别，高效的搜素
#
# # 树的概览
# 主要特征：
# 1. 每个项都有多个子节点
# 2. 除了根，其他项都只有一个父节点

# %% [markdown]
# ## 树的术语
# ![C10%201.PNG](attachment:C10%201.PNG)
#
# ## 普通的树和二叉树
# 二叉树：一个二叉树要么为空，要么包含一个根节点外加一个左子树和一个右子树。
#
# # 为什么要使用树
# **二叉搜索树**：一个给定的节点的左子树中的每一个节点，都小于该节点，而其右子树中的节点都大于该节点。
#
# 二叉搜素书支持对数时间级别的搜索，插入和删除
#
# # 二叉树的形状
# 一种极端情况：线性链
#
# 另一种极端情况：满二叉树full binary tree
#
# 满二叉节点与高度的关系：$ N = 1+2+5+...+2H $
# 反之：$ H = log_2(N+1)-1 $
#
# 完全二叉树：填充每一层再移动到下一层，除了最后一层其他都是满的。

# %% [markdown]
# # 二叉树的三种常见应用
# ## 堆
# 最小堆：每一个节点都小于或等于其两个子节点的一个二叉树
# ![C10%202.PNG](attachment:C10%202.PNG)
#
# 支持一种高效的排序算法---堆排序算法：堆排序算法通过数据集来构建堆，然后重复地删除根节点的项，然后重复地删除根节点的项，并且将其添加到一个列表的末尾。
#
# ## 二叉搜索树（BST）
# 给定节点左子树中的节点小于它，其右子树的节点大于它。
#
# 搜索时间完美平衡的二叉树时是O(logn),最坏情况当树为链表状时是O(n)
#
# ## 表达式树
# ![C10%203.PNG](attachment:C10%203.PNG)

# %% [markdown]
# # 二叉树的遍历
# ## 前序遍历
# ![C10%204.PNG](attachment:C10%204.PNG)
# ## 中序遍历
# ![C10%205.PNG](attachment:C10%205.PNG)
# ## 后序遍历
# ![C10%206.PNG](attachment:C10%206.PNG)
# ## 层序遍历
# ![C10%207.PNG](attachment:C10%207.PNG)

# %% [markdown]
# # 开发二叉搜素树
# ## 二叉搜索树接口
# 每个遍历方法返回一个迭代器，__iter__方法支持前序遍历
#
# str方法返回一个表示树形状的一个字符串
#
# ![C10%208.PNG](attachment:C10%208.PNG)
#
# ## 链表实现的数据结构
# 每一项都是类型BSTNode的一个节点对象。
#
# 外部链接到这个结构是名为self._root

# %% [markdown]
# ### 搜索二叉搜索树
# ### 遍历二叉搜索树
# 其中iter谦虚遍历利用了一个栈的方法
# ### 二叉搜索树的字符串表示
# ### 在二叉搜索树中插入一项
# ### 在二叉搜索树中删除一项

# %%
"""
File: linkedbst.py
Author: Ken Lambert
"""

from abstractcollection import AbstractCollection
from bstnode import BSTNode
from linkedstack import LinkedStack
from linkedqueue import LinkedQueue

class LinkedBST(AbstractCollection):
    """An link-based binary search tree implementation."""

    def __init__(self, sourceCollection = None):
        """Sets the initial state of self, which includes the
        contents of sourceCollection, if it's present."""
        self._root = None
        AbstractCollection.__init__(self, sourceCollection)
        
    # Accessor methods
    def __str__(self):
        """Returns a string representation with the tree rotated
        90 degrees counterclockwise."""
        def recurse(node, level):
            s = ""
            if node != None:
                s += recurse(node.right, level + 1)
                s += "| " * level
                s += str(node.data) + "\n"
                s += recurse(node.left, level + 1)
            return s
        return recurse(self._root, 0)

    def __iter__(self):
        """Supports a preorder traversal on a view of self."""
        if not self.isEmpty():
            stack = LinkedStack()
            stack.push(self._root)
            while not stack.isEmpty():
                node = stack.pop()
                yield node.data
                if node.right != None:
                    stack.push(node.right)
                if node.left != None:
                    stack.push(node.left)

    def preorder(self):
        """Supports a preorder traversal on a view of self."""
        return None

    def inorder(self):
        """Supports an inorder traversal on a view of self."""
        lyst = list()
        def recurse(node):
            if node != None:
                recurse(node.left)
                lyst.append(node.data)
                recurse(node.right)
        recurse(self._root)
        return iter(lyst)

    def postorder(self):
        """Supports an postorder traversal on a view of self."""
        lyst = list()

        def recurse(node):
            if node is not None:
                recurse(node.left)
                recurse(node.right)
                lyst.append(node.data)
        recurse(self._root)
        return iter(lyst)

    def levelorder(self):
        """Supports an levelorder traversal on a view of self."""
        lyst = list()
        queue = LinkedQueue()

        def recurse(queue):
            if not queue.isEmpty():
                temp = queue.pop()
                lyst.append(temp.data)
                if temp.right is not None:
                    queue.add(temp.right)
                if temp.left is not None:
                    queue.add(temp.left)
                recurse(queue)
        if self._root is not None:
            queue.add(self._root)
            recurse(queue)
        return iter(lyst)

    def __contains__(self, item):
        """Returns True if target is found or False otherwise."""
        return self.find(item) != None

    def find(self, item):
        """If item matches an item in self, returns the
        matched item, or None otherwise."""
        def recurse(node):
            if node is None:
                return None
            elif item == node.data:
                return node.data
            elif item < node.data:
                return recurse(node.left)
            else:
                return recurse(node.right)
        return recurse(self._root)

    # Mutator methods
    def clear(self):
        """Makes self become empty."""
        self._root = None
        self._size = 0

    def add(self, item):
        """Adds item to the tree."""

        # Helper function to search for item's position 
        def recurse(node):
            # New item is less, go left until spot is found
            if item < node.data:
                if node.left == None:
                    node.left = BSTNode(item)
                else:
                    recurse(node.left)
            # New item is greater or equal, 
            # go right until spot is found
            elif node.right == None:
                node.right = BSTNode(item)
            else:
                recurse(node.right)
            # End of recurse

        # Tree is empty, so new item goes at the root
        if self.isEmpty():
            self._root = BSTNode(item)
        # Otherwise, search for the item's spot
        else:
            recurse(self._root)
        self._size += 1

    def remove(self, item):
        """Precondition: item is in self.
        Raises: KeyError if item is not in self.
        postcondition: item is removed from self."""
        if not item in self:
            raise KeyError("Item not in tree.""")

        # Helper function to adjust placement of an item
        def liftMaxInLeftSubtreeToTop(top):
            # Replace top's datum with the maximum datum in the left subtree
            # Pre:  top has a left child
            # Post: the maximum node in top's left subtree
            #       has been removed
            # Post: top.data = maximum value in top's left subtree
            parent = top
            currentNode = top.left
            while not currentNode.right == None:
                parent = currentNode
                currentNode = currentNode.right
            top.data = currentNode.data
            if parent == top:
                top.left = currentNode.left
            else:
                parent.right = currentNode.left

        # Begin main part of the method
        if self.isEmpty(): return None
        
        # Attempt to locate the node containing the item
        itemRemoved = None
        preRoot = BSTNode(None)
        preRoot.left = self._root
        parent = preRoot
        direction = 'L'
        currentNode = self._root
        while not currentNode == None:
            if currentNode.data == item:
                itemRemoved = currentNode.data
                break
            parent = currentNode
            if currentNode.data > item:
                direction = 'L'
                currentNode = currentNode.left
            else:
                direction = 'R'
                currentNode = currentNode.right
                
        # Return None if the item is absent
        if itemRemoved == None: return None
        
        # The item is present, so remove its node

        # Case 1: The node has a left and a right child
        #         Replace the node's value with the maximum value in the
        #         left subtree
        #         Delete the maximium node in the left subtree
        if not currentNode.left == None \
           and not currentNode.right == None:
            liftMaxInLeftSubtreeToTop(currentNode)
        else:
            
        # Case 2: The node has no left child
            if currentNode.left == None:
                newChild = currentNode.right
                
        # Case 3: The node has no right child
            else:
                newChild = currentNode.left
                
        # Case 2 & 3: Tie the parent to the new child
            if direction == 'L':
                parent.left = newChild
            else:
                parent.right = newChild
            
        # All cases: Reset the root (if it hasn't changed no harm done)
        #            Decrement the collection's size counter
        #            Return the item
        self._size -= 1
        if self.isEmpty():
            self._root = None
        else:
            self._root = preRoot.left
        return itemRemoved

    def replace(self, item, newItem):
        """
        If item is in self, replaces it with newItem and
        returns the old item, or returns None otherwise."""
        probe = self._root
        while probe != None:
            if probe.data == item:
                oldData = probe.data
                probe.data = newItem
                return oldData
            elif probe.data > item:
                probe = probe.left
            else:
                probe = probe.right
        return None

# %% [markdown]
# ### 复杂度分析
# 插入和删除都需要搜索目标项，其行为接近对数级别
#
# 中序遍历获取树的项得到排序的数据，add方法添加到另一个树会变成线性形状的树，因为add方法判断总是大于第一个节点
#
# 前序遍历获取树的项得到排序的数据，add到另一个树则会生成一个新树，其形状和最初的树相同。

# %% [markdown]
# # 二叉树的数组实现
# 在基于数组的实现中，元素是按照层级来存储的。对于位置i的任意项，很容易确定相关项的位置。
# ![C10%209.PNG](attachment:C10%209.PNG)

# %% [markdown]
# # 堆
# 使用堆来实现一个优先队列
#
# 堆接口
# ![C10%2010.PNG](attachment:C10%2010.PNG)
#
# add方法接收一个元素放在一个比他小的元素之下，如果重复元素就放在之前输入的元素之下
#
# pop方法删除堆中顶端元素并返回它
#
# add方法：
# 1. 在堆的底部插入元素。
# 2. 只要这个新元素小于父节点的值，就让这个新元素向上走
#
# _heap引用一个python列表

# %%
def add(self, item):
        self._size += 1
        self._heap.append(item)
        curPos = len(self._heap) - 1
        while curPos > 0:
            parent = (curPos - 1) // 2
            parentItem = self._heap[parent]
            if parentItem <= item:
                break
            else:
                self._heap[curPos] = self._heap[parent]
                self._heap[parent] = item
                curPos = parent

# %% [markdown]
# pop方法：：
# 1. 保存堆中的顶部元素，将底部元素从堆的底部移动到顶部
# 2. 从顶部往下走，将小的元素往上移动。

# %%
def pop(self):
        if self.isEmpty():
            raise Exception("Heap is empty")
        self._size -= 1
        topItem = self._heap[0]
        bottomItem = self._heap.pop(len(self._heap) - 1)
        if len(self._heap) == 0:
            return bottomItem
           
        self._heap[0] = bottomItem
        lastIndex = len(self._heap) - 1
        curPos = 0
        while True:
            leftChild = 2 * curPos + 1 
            rightChild = 2 * curPos + 2
            if leftChild > lastIndex:
                break
            if rightChild > lastIndex:
                maxChild = leftChild;
            else:
                leftItem  = self._heap[leftChild]
                rightItem = self._heap[rightChild]
                if leftItem < rightItem:
                    maxChild = leftChild
                else:
                    maxChild = rightChild
            maxItem = self._heap[maxChild]
            if bottomItem <= maxItem:
                break
            else:
                self._heap[curPos] = self._heap[maxChild]
                self._heap[maxChild] = bottomItem
                curPos = maxChild
        return topItem

# %% [markdown]
# add和pop最多需要比较次数$log_2n$。当线性链的情况是，操作为O(n)

# %% [markdown]
# # Summary
# 1. 树是层级式的集合。树的根位于层级0.
# 2. 二叉树中，节点最多可以有两个子节点。完全二叉树，会填充完每一层的节点然后再移动到下一层。满二叉树，包括了每一个层级上所有可能的节点。
# 3. 四种遍历类型
# 4. 表达式树叶子节点包含运算数，内部节点包含运算符。
# 5. 二叉搜索树，每一个非空的左子树所包含的数据小于其父节点中的数据，右子树包含的数据都大于父节点中的数据
# 6. 二叉搜索树如果接近于完全的话，支持对数时间的搜索和插入
# 7. 堆是这样一种二叉树，其中，较小的项接近于根节点（堆顶）
